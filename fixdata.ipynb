# %%
import pandas as pd
from sklearn import preprocessing

# %%
df = pd.read_csv("SP500Historical.csv")

# %%
df['target0'] = (df['type'] == 'Iris-setosa').astype(int)

# %%
df['target1'] = (df['type'] == 'Iris-versicolor').astype(int)

# %%
df['target2'] = (df['type'] == 'Iris-virginica').astype(int)

# %%
x = df.values #returns a numpy array
cols = df.columns
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df = pd.DataFrame(x_scaled,columns=cols)

# %%
df.to_csv("SP500Hist-norm.csv",index=False)

# %%
df
# Out:
#             Close      Volume  PrevDayClose  PrevDayVol  2PrevDayClose  \
# 0      921.229980  5713390000    918.369995  4684010000     910.710022
# 1      893.039978  4903940000    921.229980  5713390000     918.369995
# 2      895.099976  5071020000    893.039978  4903940000     921.229980
# 3      900.940002  4636720000    895.099976  5071020000     893.039978
# 4      920.260010  4911240000    900.940002  4636720000     895.099976
# 5      918.900024  6076660000    920.260010  4911240000     900.940002
# 6      927.229980  4211760000    918.900024  6076660000     920.260010
# 7      919.320007  4627570000    927.229980  4211760000     918.900024
# 8      923.330017  3919400000    919.320007  4627570000     927.229980
# 9      896.419983  3931000000    923.330017  3919400000     919.320007
# 10     898.719971  4712580000    896.419983  3931000000     923.330017
# 11     881.030029  4673300000    898.719971  4712580000     896.419983
# ...
